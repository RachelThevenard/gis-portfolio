# %% [markdown]
# # Using Python to Create Useful Raster Data from Climate.ca's Climate Variables
#
# [Climatedata.ca](https://www.climatedata.ca) is the product of a collaboration between Environment and Climate Change Canada (ECCC), the Computer Research Insitute of Montréal, Ouranos, the Pacific Climate Impacts Consortium (PCIC), the Prairie Climate Centre (PCC), and HabitatSeven.
#
# Climatedata.ca provides free and open access to climate data. This includes both future climate projections and historical data. [Instructions](https://climatedata.ca/learn/#module-5) to download climata data are provided on the website.
#
# The climate data is provided in 10x6 point layers, with points for each year superimposed upon each other.

# %% [markdown]
# Using the Time Series activation properties in ArcGIS Pro, a user can scroll through the data and see how the points change over time.
#
# However, these small points are quite difficult to see. It is also difficult to infer how a the value of a point in between the visible points might differ from the recorded values.
#
# This means, if someone were to ask us, "What was the level of precipitation at X point in Y year", we would have to hope that the X point fell perfectly into the same location as a point in the data. This is very unlikely!

# %% [markdown]
# To fix this problem, we set out to create a Python script that would produce raster datasets of each climate variable for each year. We will use two types of interpolation: Kriging, and Empirical Bayesian Kriging, to examine the results of each method.

# %% [markdown]
# ## The data
# The data used for this project was focused on the Annapolis County in Nova Scotia, Canada. Climatedata.ca was used to batch-download 35 different climate variables covering the Annapolis County. The area of the county required 78 points to cover. The data included historical data as far back as 1950, and climate projection up until 2100 (151 years total). All climate variables were depicted across three different climate scenarios (RCP 2.6, RCP 4.5, and RCP 8.5). [LINK HERE]()
#
# The resulting 35 point layers each contained 11,778 points (151 x 78 = 11,778) across 78 locations. In other words, the 78 data points for each year from 1950 to 2100 were stacked on top of each other in each climate data layer.

# %% [markdown]
# # Step 0: Import libraries and set environment parameters

# %%
import os 
import arcpy, datetime
from arcpy.sa import *

# %%
arcpy.env.overwriteOutput = True

# %% [markdown]
# # Step 1: Create a point layer for each year of data
#
# Instead of having one layer with 11,778 points representing 151 years of data for each climate variable, it would be more useful to have a layer representing each climate variable for a particular year.
#
# We will create a new layer for each year, from 1950 to 2100, for each climate variable.
#
# We will also create a new geodatabase for all of these points to go into.
#
# <a id='Climate_Points_Output_Geodatabase'></a>

# %%
# Set the location where all the original climate variable layers are stored
file_gdb = r'D:\COGS_Term2\ACFA_TermProject\ClimateScripting\final_test.gdb'

# %%
# Set "Parent" folder where all folders and Geodatabases will output
gdb_folder = r'D:\COGS_Term2\ACFA_TermProject\ClimateScripting'

# %%
# Set the name for the output geodatabase where all 151 output layers
# for each climate variable should go
out_gdb_name = 'Climate_final_test_output.gdb'

# %%
# Set the location for a new geodatabase where all 151 output layers 
# for each climate variable should go
output_gdb = os.path.join(gdb_folder, out_gdb_name)

# %%
# Create output geodatabase where all 151 output layers for each climate
# variable should go
if arcpy.Exists(output_gdb) == False:
    arcpy.management.CreateFileGDB(gdb_folder, out_gdb_name)

# %%
# Set the workspace to the location where all the original climate variable 
# layers are stored
arcpy.env.workspace = file_gdb

# %%
# Store a list of all the feature classes (all the point layers) that we 
# will be putting through this script.
fclasses = arcpy.ListFeatureClasses()

# %%
# View the list of all feature classes to be manipulated.
fclasses
# Out:
# ['all_BCCAQv2_var_annual_tx_mean_FC_elev']

# %% [markdown]
# ### Step 1.1: Re-project point layers to UTM
# We want to convert the data from WGS 84 to UTM Zone 20N for use in future projects.

# %%
# Name of Geodatabase for projected data
gdb_name = 'Climate_final_test_Project.gdb'

# %%
# Full file path of Geodatabase for projected data
project_gdb = os.path.join(gdb_folder, gdb_name)

# %%
# Create new GDB for projected data
if arcpy.Exists(project_gdb) == False:
    arcpy.management.CreateFileGDB(gdb_folder, gdb_name)

# %%
# Re-project data
for fclass in fclasses:
    out_coord = arcpy.SpatialReference('NAD 1983 CSRS UTM Zone 20N')
    out_fclass = os.path.join(project_gdb, fclass)
    arcpy.management.Project(fclass, out_fclass, out_coord)

# %% [markdown]
# ### Step 1.2 Create a point layer for every year of data

# %%
# Re-set workspace to GDB with projected data
arcpy.env.workspace = project_gdb
# Update the fclasses variable to store the list of new projected point layers
fclasses = arcpy.ListFeatureClasses()

# %%
for fclass in fclasses:
    print(fclass.split('_elev')[0])
# Out:
# all_BCCAQv2_var_annual_tx_mean_FC

# %%
# Create a point layer for every year of data

try:
    for fclass in fclasses:
        year = 1950
        fc_time = "timestamp '{}-01-01 00:00:00'".format(year)
        print('The feature class name is: {}'.format(fclass))
        while year <= 2100:
            print('Selecting points with {} in feature class'.format(fc_time))
            
            # create an sql where statement to find the date
            where = "time = " + "%s" %fc_time
            
            # split the fclass name for a nicer layer name
            lyr = fclass.split('_elev')[0]

            # Make a layer from the feature class
            arcpy.management.MakeFeatureLayer(fclass, lyr)
            
            # select statement using our where statement
            arcpy.SelectLayerByAttribute_management(lyr, "NEW_SELECTION", where)
            
            # create a file name by adding the time to the fclass name
            f_name = lyr + str(year)
            print('The name of the new layer made from selected points is: {}'.format(f_name))
            # create a file path for export to the output gdb using the new file name
            f_path = os.path.join(output_gdb, f_name)
            print('File path for new layer: {}'.format(f_path))
            
            # Write the selected features to new featureclass using file path
            arcpy.CopyFeatures_management(lyr, f_path)
            #fc_time = fc_time + timedelta(days=365)
            year = year + 1
            fc_time = "timestamp '{}-01-01 00:00:00'".format(year)

except:
    print(arcpy.GetMessages())
        
# read more about datetime module: https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior
# Out:
# The feature class name is: all_BCCAQv2_var_annual_tx_mean_FC_elev
# Selecting points with timestamp '1950-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1950
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1950
# Selecting points with timestamp '1951-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1951
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1951
# Selecting points with timestamp '1952-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1952
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1952
# Selecting points with timestamp '1953-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1953
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1953
# Selecting points with timestamp '1954-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1954
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1954
# Selecting points with timestamp '1955-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1955
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1955
# Selecting points with timestamp '1956-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1956
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1956
# Selecting points with timestamp '1957-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1957
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1957
# Selecting points with timestamp '1958-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1958
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1958
# Selecting points with timestamp '1959-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1959
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1959
# Selecting points with timestamp '1960-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1960
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1960
# Selecting points with timestamp '1961-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1961
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1961
# Selecting points with timestamp '1962-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1962
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1962
# Selecting points with timestamp '1963-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1963
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1963
# Selecting points with timestamp '1964-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1964
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1964
# Selecting points with timestamp '1965-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1965
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1965
# Selecting points with timestamp '1966-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1966
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1966
# Selecting points with timestamp '1967-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1967
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1967
# Selecting points with timestamp '1968-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1968
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1968
# Selecting points with timestamp '1969-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1969
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1969
# Selecting points with timestamp '1970-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1970
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1970
# Selecting points with timestamp '1971-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1971
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1971
# Selecting points with timestamp '1972-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1972
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1972
# Selecting points with timestamp '1973-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1973
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1973
# Selecting points with timestamp '1974-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1974
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1974
# Selecting points with timestamp '1975-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1975
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1975
# Selecting points with timestamp '1976-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1976
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1976
# Selecting points with timestamp '1977-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1977
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1977
# Selecting points with timestamp '1978-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1978
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1978
# Selecting points with timestamp '1979-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1979
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1979
# Selecting points with timestamp '1980-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1980
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1980
# Selecting points with timestamp '1981-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1981
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1981
# Selecting points with timestamp '1982-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1982
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1982
# Selecting points with timestamp '1983-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1983
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1983
# Selecting points with timestamp '1984-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1984
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1984
# Selecting points with timestamp '1985-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1985
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1985
# Selecting points with timestamp '1986-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1986
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1986
# Selecting points with timestamp '1987-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1987
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1987
# Selecting points with timestamp '1988-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1988
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1988
# Selecting points with timestamp '1989-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1989
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1989
# Selecting points with timestamp '1990-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1990
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1990
# Selecting points with timestamp '1991-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1991
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1991
# Selecting points with timestamp '1992-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1992
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1992
# Selecting points with timestamp '1993-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1993
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1993
# Selecting points with timestamp '1994-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1994
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1994
# Selecting points with timestamp '1995-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1995
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1995
# Selecting points with timestamp '1996-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1996
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1996
# Selecting points with timestamp '1997-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1997
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1997
# Selecting points with timestamp '1998-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1998
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1998
# Selecting points with timestamp '1999-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC1999
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC1999
# Selecting points with timestamp '2000-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2000
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2000
# Selecting points with timestamp '2001-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2001
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2001
# Selecting points with timestamp '2002-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2002
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2002
# Selecting points with timestamp '2003-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2003
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2003
# Selecting points with timestamp '2004-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2004
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2004
# Selecting points with timestamp '2005-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2005
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2005
# Selecting points with timestamp '2006-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2006
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2006
# Selecting points with timestamp '2007-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2007
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2007
# Selecting points with timestamp '2008-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2008
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2008
# Selecting points with timestamp '2009-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2009
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2009
# Selecting points with timestamp '2010-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2010
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2010
# Selecting points with timestamp '2011-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2011
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2011
# Selecting points with timestamp '2012-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2012
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2012
# Selecting points with timestamp '2013-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2013
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2013
# Selecting points with timestamp '2014-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2014
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2014
# Selecting points with timestamp '2015-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2015
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2015
# Selecting points with timestamp '2016-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2016
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2016
# Selecting points with timestamp '2017-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2017
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2017
# Selecting points with timestamp '2018-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2018
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2018
# Selecting points with timestamp '2019-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2019
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2019
# Selecting points with timestamp '2020-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2020
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2020
# Selecting points with timestamp '2021-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2021
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2021
# Selecting points with timestamp '2022-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2022
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2022
# Selecting points with timestamp '2023-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2023
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2023
# Selecting points with timestamp '2024-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2024
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2024
# Selecting points with timestamp '2025-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2025
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2025
# Selecting points with timestamp '2026-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2026
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2026
# Selecting points with timestamp '2027-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2027
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2027
# Selecting points with timestamp '2028-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2028
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2028
# Selecting points with timestamp '2029-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2029
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2029
# Selecting points with timestamp '2030-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2030
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2030
# Selecting points with timestamp '2031-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2031
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2031
# Selecting points with timestamp '2032-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2032
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2032
# Selecting points with timestamp '2033-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2033
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2033
# Selecting points with timestamp '2034-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2034
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2034
# Selecting points with timestamp '2035-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2035
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2035
# Selecting points with timestamp '2036-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2036
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2036
# Selecting points with timestamp '2037-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2037
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2037
# Selecting points with timestamp '2038-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2038
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2038
# Selecting points with timestamp '2039-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2039
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2039
# Selecting points with timestamp '2040-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2040
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2040
# Selecting points with timestamp '2041-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2041
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2041
# Selecting points with timestamp '2042-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2042
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2042
# Selecting points with timestamp '2043-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2043
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2043
# Selecting points with timestamp '2044-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2044
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2044
# Selecting points with timestamp '2045-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2045
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2045
# Selecting points with timestamp '2046-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2046
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2046
# Selecting points with timestamp '2047-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2047
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2047
# Selecting points with timestamp '2048-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2048
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2048
# Selecting points with timestamp '2049-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2049
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2049
# Selecting points with timestamp '2050-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2050
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2050
# Selecting points with timestamp '2051-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2051
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2051
# Selecting points with timestamp '2052-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2052
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2052
# Selecting points with timestamp '2053-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2053
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2053
# Selecting points with timestamp '2054-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2054
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2054
# Selecting points with timestamp '2055-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2055
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2055
# Selecting points with timestamp '2056-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2056
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2056
# Selecting points with timestamp '2057-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2057
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2057
# Selecting points with timestamp '2058-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2058
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2058
# Selecting points with timestamp '2059-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2059
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2059
# Selecting points with timestamp '2060-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2060
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2060
# Selecting points with timestamp '2061-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2061
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2061
# Selecting points with timestamp '2062-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2062
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2062
# Selecting points with timestamp '2063-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2063
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2063
# Selecting points with timestamp '2064-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2064
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2064
# Selecting points with timestamp '2065-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2065
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2065
# Selecting points with timestamp '2066-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2066
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2066
# Selecting points with timestamp '2067-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2067
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2067
# Selecting points with timestamp '2068-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2068
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2068
# Selecting points with timestamp '2069-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2069
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2069
# Selecting points with timestamp '2070-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2070
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2070
# Selecting points with timestamp '2071-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2071
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2071
# Selecting points with timestamp '2072-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2072
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2072
# Selecting points with timestamp '2073-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2073
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2073
# Selecting points with timestamp '2074-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2074
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2074
# Selecting points with timestamp '2075-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2075
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2075
# Selecting points with timestamp '2076-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2076
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2076
# Selecting points with timestamp '2077-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2077
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2077
# Selecting points with timestamp '2078-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2078
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2078
# Selecting points with timestamp '2079-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2079
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2079
# Selecting points with timestamp '2080-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2080
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2080
# Selecting points with timestamp '2081-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2081
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2081
# Selecting points with timestamp '2082-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2082
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2082
# Selecting points with timestamp '2083-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2083
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2083
# Selecting points with timestamp '2084-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2084
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2084
# Selecting points with timestamp '2085-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2085
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2085
# Selecting points with timestamp '2086-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2086
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2086
# Selecting points with timestamp '2087-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2087
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2087
# Selecting points with timestamp '2088-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2088
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2088
# Selecting points with timestamp '2089-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2089
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2089
# Selecting points with timestamp '2090-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2090
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2090
# Selecting points with timestamp '2091-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2091
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2091
# Selecting points with timestamp '2092-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2092
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2092
# Selecting points with timestamp '2093-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2093
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2093
# Selecting points with timestamp '2094-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2094
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2094
# Selecting points with timestamp '2095-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2095
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2095
# Selecting points with timestamp '2096-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2096
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2096
# Selecting points with timestamp '2097-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2097
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2097
# Selecting points with timestamp '2098-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2098
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2098
# Selecting points with timestamp '2099-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2099
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2099
# Selecting points with timestamp '2100-01-01 00:00:00' in feature class
# The name of the new layer made from selected points is: all_BCCAQv2_var_annual_tx_mean_FC2100
# File path for new layer: D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Climate_final_test_output.gdb\all_BCCAQv2_var_annual_tx_mean_FC2100

# %% [markdown]
# # Step 2: Create a raster for each point file layer
#
# We will create a geodatabase for each climate variable. This will ensure that the rasters for each climate variable are stored in their own dedicated place for future use.
# Need a reminder of the file path for output_gdb? Return to [this section](#Climate_Points_Output_Geodatabase).

# %%
# Change the workspace to the geodatabase containing the feature classes 
# representing each year for each climate variable that we just created
arcpy.env.workspace = output_gdb

# %%
# Store a list of all the 151 point layers for each climate variable created
# This will be a long list!
new_fclasses = arcpy.ListFeatureClasses()

# %%
# Check the length of the list we just created
len(new_fclasses)
# Out:
# 151

# %% [markdown]
# ### Step 2.1: Selecting the climate scenario
# As previously discussed, all values for each climate variable are available across three scenarios, or RCP's.
# RCP stands for 'Representative Concentration Pathway'. The RCP's try to predict how human activities will impact concentrations of greenhouse gases in the atmosphere. For example, will we continue to burn fossil fuels, or will we shift towards renewable energy?
# - RCP 2.6: With **high levels** of effort to curb emissions, the RCP2.6 pathway is achieved. A 1.0&deg;C average increase in temperature is expected, below the threshold at which climate change becomes dangerous (2&deg;C).
# - RCP 4.5: With **medium** levels of effort to curb emissions, the RCP4.5 pathway is acheived. A 2.2&deg;C average increase in temperature is expected, above the threshold at while climate change becomes dangerous (2&deg;C).
# - RCP 8.5: With **low** levels of effort to curb emissions, the RCP8.5 pathway is acheived. Current emissions are tracking close to the RCP8.5 pathway. A 3.7&deg;C average increase in temperature is expected, above the threshold at which climate change becomes dangerous (2&deg;C)
#
# We will now choose which scenario we will model in our rasters.

# %%
# Choose climate scenario: one of rcp26, rcp45, or rcp85
rcp = "rcp85"
# Choose model percentile
p = "p90"

# %% [markdown]
# ### Step 2.2: Ordinary kriging

# %%
# Create a file name for the new folder to hold all unique geodatabases
# for each climate feature undergoing ordinary kriging
ord_kriging_folder = 'Ordinary_Kriging_final_test_Output_Geodatabases'

# %%
# Create a new folder to hold all unique geodatabases for each 
# climate feature
if arcpy.Exists(ord_kriging_folder) ==False:
    arcpy.management.CreateFolder(gdb_folder, ord_kriging_folder)

# %%
# Set the path for the new folder that will hold all unique
# geodatabases for each climate feature
out_folder = os.path.join(gdb_folder, ord_kriging_folder)

# %%
for fc in new_fclasses:
    fields = [f.name for f in arcpy.ListFields(fc)]
    filter_field = filter(lambda a: a.startswith(rcp) and a.endswith(p), fields)
    field = list(filter_field)
    field_str = ''.join(map(str, field))
    print(field_str)
# Out:
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90
# rcp85_tx_mean_p90

# %%
# Create a new file geodatabase for each climate feature
# Perform ordinary kriging on each point layer created for 
# each year of each climate feature
# Save all new rasters to the appropriate geodatabases

try:
    for fc in new_fclasses:
        fields = [f.name for f in arcpy.ListFields(fc)]
        filter_field = filter(lambda a: a.startswith(rcp) and a.endswith(p), fields)
        field = list(filter_field)
        field_str = ''.join(map(str, field))
        f_name = fc + "_{}{}".format(rcp,p)
        gdb_name = fc[4:-7] + '.gdb'
        gdb_path = os.path.join(out_folder, gdb_name) 
        if arcpy.Exists(gdb_path) == False:
            print('Creating file geodatabase...')
            arcpy.management.CreateFileGDB(out_folder, gdb_name) 
            print('GDB file path: {}'.format(gdb_path))
        out_path = os.path.join(gdb_path, f_name)
        #out_surface_raster = Kriging(fc, field_str, KrigingModelOrdinary("Spherical # # # #", 0.003, "VARIABLE 12", None))
        #yonkers
        #out_surface_raster = arcpy.sa.Kriging(fc, field_str, "Spherical # # # #", 44966.1061417827, "VARIABLE 12", None)
        out_surface_raster = arcpy.sa.Kriging(fc, field_str, "Spherical # # # #", 0.003, "VARIABLE 12", None)
        out_surface_raster.save(out_path)
        print('Raster added to GDB: {}'.format(f_name))
except:
    print(arcpy.GetMessages())
# Out:
# Start Time: May 19, 2022 6:57:24 AM
# ERROR 010092: Invalid output extent.
# Failed to execute (Kriging).
# Failed at May 19, 2022 6:57:24 AM (Elapsed Time: 0.46 seconds)

# %% [markdown]
# ### Step 2.3: Empirical Bayesian Kriging (EBK)

# %%
# Create a file name for the new folder to hold all unique geodatabases
# for each climate feature undergong Empirical Bayesian Kriging (EBK)
ebk_folder = 'EBK_Output_Geodatabases'

# %%
# Create a new folder to hold all unique geodatabases for each 
# climate feature
arcpy.management.CreateFolder(gdb_folder, ebk_folder)
# Out:
# <Result 'D:\\COGS_Term2\\ACFA_TermProject\\ClimateScripting\\EBK_Output_Geodatabases'>

# %%
# Set the path for the new folder that will hold all unique
# geodatabases for each climate feature
out_ebk_folder = os.path.join(gdb_folder, ebk_folder)

# %%
for fc in new_fclasses:
    name = fc.split('all_BCCAQv2_var_annual_')[1].replace('_','').replace('FC','')
    print(name)
# Out:
# tnmean1950
# tnmean1951
# tnmean1952
# tnmean1953
# tnmean1954
# tnmean1955
# tnmean1956
# tnmean1957
# tnmean1958
# tnmean1959
# tnmean1960
# tnmean1961
# tnmean1962
# tnmean1963
# tnmean1964
# tnmean1965
# tnmean1966
# tnmean1967
# tnmean1968
# tnmean1969
# tnmean1970
# tnmean1971
# tnmean1972
# tnmean1973
# tnmean1974
# tnmean1975
# tnmean1976
# tnmean1977
# tnmean1978
# tnmean1979
# tnmean1980
# tnmean1981
# tnmean1982
# tnmean1983
# tnmean1984
# tnmean1985
# tnmean1986
# tnmean1987
# tnmean1988
# tnmean1989
# tnmean1990
# tnmean1991
# tnmean1992
# tnmean1993
# tnmean1994
# tnmean1995
# tnmean1996
# tnmean1997
# tnmean1998
# tnmean1999
# tnmean2000
# tnmean2001
# tnmean2002
# tnmean2003
# tnmean2004
# tnmean2005
# tnmean2006
# tnmean2007
# tnmean2008
# tnmean2009
# tnmean2010
# tnmean2011
# tnmean2012
# tnmean2013
# tnmean2014
# tnmean2015
# tnmean2016
# tnmean2017
# tnmean2018
# tnmean2019
# tnmean2020
# tnmean2021
# tnmean2022
# tnmean2023
# tnmean2024
# tnmean2025
# tnmean2026
# tnmean2027
# tnmean2028
# tnmean2029
# tnmean2030
# tnmean2031
# tnmean2032
# tnmean2033
# tnmean2034
# tnmean2035
# tnmean2036
# tnmean2037
# tnmean2038
# tnmean2039
# tnmean2040
# tnmean2041
# tnmean2042
# tnmean2043
# tnmean2044
# tnmean2045
# tnmean2046
# tnmean2047
# tnmean2048
# tnmean2049
# tnmean2050
# tnmean2051
# tnmean2052
# tnmean2053
# tnmean2054
# tnmean2055
# tnmean2056
# tnmean2057
# tnmean2058
# tnmean2059
# tnmean2060
# tnmean2061
# tnmean2062
# tnmean2063
# tnmean2064
# tnmean2065
# tnmean2066
# tnmean2067
# tnmean2068
# tnmean2069
# tnmean2070
# tnmean2071
# tnmean2072
# tnmean2073
# tnmean2074
# tnmean2075
# tnmean2076
# tnmean2077
# tnmean2078
# tnmean2079
# tnmean2080
# tnmean2081
# tnmean2082
# tnmean2083
# tnmean2084
# tnmean2085
# tnmean2086
# tnmean2087
# tnmean2088
# tnmean2089
# tnmean2090
# tnmean2091
# tnmean2092
# tnmean2093
# tnmean2094
# tnmean2095
# tnmean2096
# tnmean2097
# tnmean2098
# tnmean2099
# tnmean2100

# %%
# Perform Empirical Bayesian Kriging

try:
    for fc in new_fclasses:
        fields = [f.name for f in arcpy.ListFields(fc)]
        filter_field = filter(lambda a: a.startswith(rcp) and a.endswith(p), fields)
        field = list(filter_field)
        field_str = ''.join(map(str, field))
        f_name = fc.split('all_BCCAQv2_var_annual_')[1].replace('_','').replace('FC','')
        gdb_name = fc[4:-7] + '_{}{}_EBK.gdb'.format(rcp,p) 
        gdb_path = os.path.join(out_ebk_folder, gdb_name) 
        if arcpy.Exists(gdb_path) == False:
            print('Creating file geodatabase...')
            arcpy.management.CreateFileGDB(out_ebk_folder, gdb_name) 
            print(gdb_path)
        out_path = os.path.join(gdb_path, f_name)
        arcpy.ga.EmpiricalBayesianKriging(fc, field_str, None, out_path, 319.0023464, "NONE", 100, 1, 100, "NBRTYPE=StandardCircular RADIUS=28770.3543520455 ANGLE=0 NBR_MAX=15 NBR_MIN=10 SECTOR_TYPE=ONE_SECTOR", "PREDICTION", 0.5, "EXCEED", None, "POWER")
        print(out_path)
except:
    print(arcpy.GetMessages())
# Out:
# Creating file geodatabase...
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1950
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1951
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1952
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1953
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1954
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1955
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1956
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1957
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1958
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1959
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1960
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1961
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1962
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1963
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1964
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1965
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1966
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1967
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1968
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1969
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1970
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1971
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1972
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1973
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1974
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1975
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1976
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1977
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1978
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1979
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1980
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1981
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1982
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1983
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1984
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1985
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1986
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1987
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1988
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1989
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1990
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1991
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1992
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1993
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1994
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1995
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1996
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1997
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1998
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean1999
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2000
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2001
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2002
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2003
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2004
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2005
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2006
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2007
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2008
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2009
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2010
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2011
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2012
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2013
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2014
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2015
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2016
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2017
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2018
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2019
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2020
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2021
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2022
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2023
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2024
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2025
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2026
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2027
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2028
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2029
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2030
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2031
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2032
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2033
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2034
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2035
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2036
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2037
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2038
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2039
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2040
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2041
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2042
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2043
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2044
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2045
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2046
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2047
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2048
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2049
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2050
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2051
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2052
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2053
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2054
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2055
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2056
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2057
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2058
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2059
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2060
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2061
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2062
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2063
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2064
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2065
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2066
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2067
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2068
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2069
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2070
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2071
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2072
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2073
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2074
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2075
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2076
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2077
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2078
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2079
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2080
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2081
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2082
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2083
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2084
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2085
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2086
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2087
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2088
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2089
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2090
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2091
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2092
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2093
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2094
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2095
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2096
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2097
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2098
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2099
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\EBK_Output_Geodatabases\BCCAQv2_var_annual_tn_mean_rcp85p90_EBK.gdb\tnmean2100

# %% [markdown]
# # Step 3: Adding the Rasters to Mosaic Datasets
#
# At this point we will begin adding our rasters to Raster Mosaic Datasets.
# We will use a format that will allow Time Series activation later on.

# %% [markdown]
# ## Step 3.1 Adding the Rasters to Mosaic Datasets: Ordinary Kriging

# %%
# Change the workspace to the folder that now contains the geodatabases for 
# each feature
arcpy.env.workspace = out_folder

# %%
# Store a list of all workspaces within our current workspace
ws = arcpy.ListWorkspaces()
# Display a list of all workspaces within our current workspace
ws

# %%
# Create a name for the new Geodatabase that we will create to hold 
# all Raster Mosaic Datasets
gdb_name = 'ClimateMosaics_OrdinaryKriging.gdb'

# %%
# Create a new file gdb to contain the final mosaic datasets
arcpy.management.CreateFileGDB(out_folder, gdb_name)
# Out:
# <Result 'D:\\COGS_Term2\\ACFA_TermProject\\ClimateScripting\\Test_Outputs2\\ClimateMosaics.gdb'>

# %%
# Set the file path for the new Geodatabase that will hold all 
# Raster Mosaic Datasets
out_gdb = os.path.join(out_folder, gdb_name)

# %% [markdown]
# ### Step 3.1.1 Creating a raster mosaic dataset for each climate variable and adding rasters

# %%
# Create mosaic dataset for each feature and import all relevant rasters
# If mosaic dataset already exists due to re-running data, delete and recreate
# Add rasters to new mosaics

for w in ws:
    print('Current geodatabase: {}'.format(w))
    m_name = w.split('\\')[5][:-4]
    m_path = os.path.join(out_gdb, m_name)
    coord = arcpy.SpatialReference("NAD 1983 CSRS UTM Zone 20N")
    if arcpy.Exists(m_path):
        arcpy.management.DeleteMosaicDataset(m_name)
    arcpy.management.CreateMosaicDataset(out_gdb, m_name, coord)
    arcpy.management.AddRastersToMosaicDataset(m_path, "Raster Dataset", w, "UPDATE_CELL_SIZES", "UPDATE_BOUNDARY", "UPDATE_OVERVIEWS", None, 0, 1500, None, '', "SUBFOLDERS", "ALLOW_DUPLICATES", "NO_PYRAMIDS", "CALCULATE_STATISTICS", "NO_THUMBNAILS", '', "NO_FORCE_SPATIAL_REFERENCE", "ESTIMATE_STATISTICS", None, "NO_PIXEL_CACHE")
    print('Added rasters from current geodatabase into new Raster Mosaic Dataset.')
    print('Location of new Raster Mosaic Dataset: {}'.format(out_gdb))
    print('Name of new Raster Mosaic Dataset: {}'.format(m_name))
# Out:
# D:\COGS_Term2\ACFA_TermProject\ClimateScripting\Test_Outputs2\BCCAQv2_var_annual_tn_mean.gdb

# %%
# Change workspace to Climate Mosaics gdb
arcpy.env.workspace = out_gdb

# %%
# Store a list of all datasets with the Climate Mosaics geodatabase
mosaics = arcpy.ListDatasets()
# Display the list of all datasets within the Climate Mosaics geodatabase
# We should see a list of all of our Raster Mosaic Datasets
mosaics
# Out:
# ['BCCAQv2_var_annual_tn_mean']

# %% [markdown]
# ### Step 3.2.2 Add a Time field and fill it with the appropriate year
# This will allow us to use time series activation with each raster. This is the final step of the process for Ordinary Kriging!

# %%
# https://gis.stackexchange.com/questions/60810/add-a-time-dimension-in-esri-mosaic-raster-dataset

for m in mosaics:
    lst = []
    table_name = 'AMD_' + m + '_CAT'
    t = os.path.join(out_gdb, table_name)
    fields = arcpy.ListFields(t)
    for field in fields:
        lst.append(field.name)
    if 'Time' not in lst:
        arcpy.management.AddField(t, 'Time', 'SHORT')
        print("Added 'Time' field.")
    rows = arcpy.UpdateCursor(t, ['*'])
    for row in rows:
        year = int(row.name.split('_FC')[1][0:4])
        #timestring= datetime.datetime(year, 1, 1)
        row.time = year
        rows.updateRow(row)
        print(row.time)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Now that we have a raster dataset for each year for each climate variable, we can readily perform calculations and visualize changes. If we want to examine the average temperature change between two decades, for example, we can do so while viewing interpolated values across the whole study area. This script can support future academic or other research, as it provides new dimensions of use for the data at ClimateData.ca.
